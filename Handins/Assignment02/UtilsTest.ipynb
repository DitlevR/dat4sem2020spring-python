# %%
import utils
import wget

file = 'filewriteTo.csv'
path = '/Users/Rumle/Documents/DAT4/dataScience/realPython/dat4sem2020spring-python/Handins/Assignment02'
utils.writeFileNames(path,file)
utils.writeFileNamesRecursively(path, file)
utils.readFirstWord(path+'/running-cli')
utils.findEmail(path+'/running-cli')
utils.findheadlines(path+'/running-cli')
# Out:
# import sys
# import sys
# /user/ditl
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# # parser.add_argument("--arg", help="")
